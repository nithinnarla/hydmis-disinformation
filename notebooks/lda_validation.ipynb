# %% [markdown]
# # HyDMIS, LDA Topic Validation
# ## Stage 1: Topic Model Quality Assessment
#
# **Purpose:** Validate quality of trained LDA models before Stage 2 GPT-4 semantic verification.
#
# **Metrics:**
# - C_v coherence score per topic, semantic coherence of topic words
# - Inter-topic distance matrix, topic distinctiveness
#
# **Models validated:**
# - English LDA (10 topics): LIAR2 + TruthSeeker + FakeNewsNet
# - German LDA (8 topics): DeFaktS
# - Multilingual LDA (10 topics): NewsPolyML
#
# **Key findings:**
# - English C_v: 0.354 | German C_v: 0.392 | Multilingual C_v: 0.376, all moderate
# - Moderate coherence expected for short noisy social media texts
# - Inter-topic distances: 0.921-0.984, topics highly distinct across all models
# - Stage 1 LDA models validated, Stage 2 GPT-4 verification can proceed

# %%
import sys, os, warnings, logging
sys.path.insert(0, '../src')
warnings.filterwarnings('ignore'); logging.disable(logging.CRITICAL)
from IPython.display import Image
from lda_validation import run_lda_validation
print('Imports complete')
# Out:
# Imports complete

# %%
import os
os.chdir('..')  # move to repo root so data paths resolve
results = run_lda_validation()
os.chdir('notebooks')
print('Validation complete')
# Out:
# HyDMIS Phase 4, LDA Topic Validation
# ==================================================
#
# --- Loading LDA Models ---
# HyDMIS Phase 4, Stage 1: LDA Topic Modeling Pipeline
# ==========================================================
#
# --- Loading Datasets ---
# Loading LIAR2...
#    LIAR2: 22,962 records | Political | English
# Loading TruthSeeker...
#    TruthSeeker: 134,198 records | Social Media | English
# Loading FakeNewsNet...
#    FakeNewsNet: 23,196 records | News | English
# Loading DeFaktS...
#    DeFaktS: 105,855 records | Social Media | German
# Loading NewsPolyML...
#    NewsPolyML: 32,129 records | News | EN/DE/ES/FR/IT
#   LIAR2:         22,962 records
#   TruthSeeker:  134,198 records (sample: 50,000)
#   FakeNewsNet:   23,196 records
#   DeFaktS:      105,855 records (sample: 50,000)
#   NewsPolyML:    32,129 records
#
# --- English LDA Preprocessing ---
#   LIAR2 clean texts: 22,961
#   TruthSeeker clean texts: 50,000
#   FakeNewsNet clean texts: 22,664
#   Combined English corpus: 95,625 texts
#
# --- English LDA (10 topics) ---
#   Vocabulary size: 5,000
#   Log-likelihood: -8740410.1
#   Topic  0: out | he | election | your | tax | fraud | 10 | as
#   Topic  1: white | americans | house | photo | support | african | checks | best
#   Topic  2: obama | 000 | over | since | by | administration | barack | barack obama
#   Topic  3: covid | you | 19 | covid 19 | vaccine | jobs | if | go
#   Topic  4: from | her | up | now | going | show | because | by
#   Topic  5: trump | donald | donald trump | texas | voter | coronavirus | nation | country
#   Topic  6: health | marijuana | kardashian | as | even | baby | jenner | care
#   Topic  7: biden | joe | joe biden | after | video | his | minimum | wage
#   Topic  8: last | world | as | death | less | our | never | meghan
#   Topic  9: taxes | rate | she | we | highest | children | percent | know
#
# --- English Topic Distribution ---
#   Topic  0: 8,097 texts (8.5%)
#   Topic  1: 9,080 texts (9.5%)
#   Topic  2: 9,430 texts (9.9%)
#   Topic  3: 8,450 texts (8.8%)
#   Topic  4: 11,006 texts (11.5%)
#   Topic  5: 11,253 texts (11.8%)
#   Topic  6: 8,761 texts (9.2%)
#   Topic  7: 10,674 texts (11.2%)
#   Topic  8: 9,744 texts (10.2%)
#   Topic  9: 9,130 texts (9.5%)
#
# --- German LDA Preprocessing (DeFaktS) ---
#   DeFaktS clean texts: 49,340
#
# --- German LDA (8 topics) ---
#   Vocabulary size: 5,000
#   Log-likelihood: -3978218.5
#   Topic  0: so | aus | 2023 | kein | habe | eu | deutschland | jetzt
#   Topic  1: so | jetzt | diese | world | weiter | heute | gerade | endlich
#   Topic  2: ukraine | aus | krieg | will | wollen | russland | diese | grünen
#   Topic  3: frauen | deutschen | covid | gt | deutsche | jahre | tag | berlin
#   Topic  4: the | waffen | of | sicherheit | iran | während | danke | mindestlohn
#   Topic  5: mir | deutschland | politik | einfach | uns | da | putin | doch
#   Topic  6: mich | menschen | bin | kommt | einer | gut | frau | eigentlich
#   Topic  7: wieder | immer | mal | gibt | sein | hier | aus | einen
#
# --- German Topic Distribution ---
#   Topic  0: 8,421 texts (17.1%)
#   Topic  1: 5,125 texts (10.4%)
#   Topic  2: 6,496 texts (13.2%)
#   Topic  3: 5,499 texts (11.1%)
#   Topic  4: 3,906 texts (7.9%)
#   Topic  5: 5,488 texts (11.1%)
#   Topic  6: 6,057 texts (12.3%)
#   Topic  7: 8,348 texts (16.9%)
#
# --- Multilingual LDA Preprocessing (NewsPolyML) ---
#   NewsPolyML clean texts: 32,109
#
# --- Multilingual LDA (10 topics) ---
#   Vocabulary size: 5,000
#   Log-likelihood: -8786241.4
#   Topic  0: de | la | da | en | el | un | que | 2012
#   Topic  1: del | si | con | lo | alle | primo | media | periodo
#   Topic  2: euro | die | era | und | ein | ne | dice | base
#   Topic  3: 19 | covid | covid 19 | 000 | ben | 14 | 100 | data
#   Topic  4: di | il | che | la | un | della | non | le
#   Topic  5: shows | video | photo | video shows | coronavirus | photo shows | from | 2020
#   Topic  6: al | una | ha | con | 2014 | caso | ministro | europa
#   Topic  7: per | come | italia | ma | anno | ai | miliardi | prima
#   Topic  8: ed | europea | camera | 10 | aumento | by | 11 | 2016
#   Topic  9: le | der | 15 | ue | des | von | les | de
#
# --- Multilingual Topic Distribution ---
#   Topic  0: 10,242 texts (31.9%)
#   Topic  1:   425 texts (1.3%)
#   Topic  2: 3,560 texts (11.1%)
#   Topic  3: 2,968 texts (9.2%)
#   Topic  4: 3,634 texts (11.3%)
#   Topic  5: 5,696 texts (17.7%)
#   Topic  6:   567 texts (1.8%)
#   Topic  7:   682 texts (2.1%)
#   Topic  8: 1,837 texts (5.7%)
#   Topic  9: 2,498 texts (7.8%)
#
# --- Key Findings ---
#   English corpus: 95,625 texts | 10 topics identified
#   German corpus: 49,340 texts | 8 topics identified
#   Multilingual corpus: 32,109 texts | 10 topics identified
#   LDA separates health, political, and social disinformation clusters unsupervised
#   German LDA separate model, textstat FK confirmed unusable for German
#   Stage 1 complete, topic assignments ready for Stage 2 GPT-4 verification
#
# --- Saving Topic Assignments ---
#   Saved 177,074 topic assignments to /Users/nithinnarla/nithin-research/hydmis-disinformation/data/processed/lda_topic_assignments.csv
#   Columns: dataset, record_id, lda_topic_id, lda_model
#   This file did not exist before - gpt4_sampler.py previously used a hardcoded
#   lda_topic_id=-1 placeholder because no LDA output was ever persisted to disk.
#
# --- LDA Pipeline complete ---
#   3 LDA models trained: English, German, Multilingual
#   Ready for lda_train.py, hyperparameter optimization and topic coherence scoring
#   All 3 LDA models loaded
#
# --- Preparing Texts for Coherence Scoring ---
# Loading LIAR2...
#    LIAR2: 22,962 records | Political | English
# Loading TruthSeeker...
#    TruthSeeker: 134,198 records | Social Media | English
# Loading FakeNewsNet...
#    FakeNewsNet: 23,196 records | News | English
# Loading DeFaktS...
#    DeFaktS: 105,855 records | Social Media | German
# Loading NewsPolyML...
#    NewsPolyML: 32,129 records | News | EN/DE/ES/FR/IT
#   English corpus: 95,625 texts
#   German corpus: 104,518 texts
#   Multilingual corpus: 32,109 texts
#
# --- C_v Coherence Scoring ---
#   Computing English LDA coherence (10 topics)...
#   English C_v coherence: 0.3541
#   Computing German LDA coherence (8 topics)...
#   German C_v coherence: 0.3922
#   Computing Multilingual LDA coherence (10 topics)...
#   Multilingual C_v coherence: 0.3757
#
# --- Inter-Topic Distance ---
#   English mean inter-topic distance: 0.964
#   German mean inter-topic distance: 0.921
#   Multilingual mean inter-topic distance: 0.984
#
# --- Key Findings ---
#   English C_v coherence: 0.3541, moderate
#   German C_v coherence: 0.3922, moderate
#   Multilingual C_v coherence: 0.3757, moderate
#   Inter-topic distances confirm topic distinctiveness
#   Stage 1 LDA models validated, ready for Stage 2 GPT-4 verification
#   Fig 1 saved - lda_coherence_english.png
#   Fig 2 saved - lda_coherence_comparison.png
#   Fig 3 saved - lda_topic_distance_english.png
#   Fig 4 saved - lda_topic_distance_german.png
#   Fig 5 saved - lda_coherence_german.png
#   Fig 6 saved - lda_topic_distance_multilingual.png
#   Fig 7 saved - lda_coherence_multilingual.png
#
# --- LDA Validation complete ---
#   7 figures saved to figures/stage1/
#   C_v coherence validates topic quality for Stage 2 GPT-4 verification
#   Inter-topic distances confirm topic distinctiveness
# Validation complete

# %% [markdown]
# ## 1. C_v Coherence per Topic, English LDA
#
# Per-topic coherence for English LDA (10 topics). Mean C_v=0.354. Moderate coherence expected for short social media claims.

# %%
Image('../figures/stage1/lda_coherence_english.png')

# %% [markdown]
# ## 2. C_v Coherence per Topic, German LDA
#
# Per-topic coherence for German LDA (8 topics). Mean C_v=0.392, highest of 3 models. German DeFaktS tweets show slightly better topic coherence.

# %%
Image('../figures/stage1/lda_coherence_german.png')

# %% [markdown]
# ## 3. C_v Coherence Comparison, All Models
#
# C_v coherence across all three LDA models. German model achieves highest coherence (0.392). All models moderate but acceptable.

# %%
Image('../figures/stage1/lda_coherence_comparison.png')

# %% [markdown]
# ## 4. Inter-Topic Distance, English LDA
#
# Pairwise cosine distance between English topics. Mean=0.964, highly distinct. Topics capture separate content domains (political, health, celebrity).

# %%
Image('../figures/stage1/lda_topic_distance_english.png')

# %% [markdown]
# ## 5. Inter-Topic Distance, German LDA
#
# Pairwise cosine distance between German topics. Mean=0.921, highly distinct. Ukraine/Russia, COVID, and political topics clearly separated.

# %%
Image('../figures/stage1/lda_topic_distance_german.png')

# %% [markdown]
# ## 6. Inter-Topic Distance, Multilingual LDA
#
# Pairwise cosine distance between Multilingual topics. Mean=0.984, highest distinctiveness of all 3 models. Cross-lingual topics maximally distinct.

# %%
Image('../figures/stage1/lda_topic_distance_multilingual.png')

# %% [markdown]
# ## 7. C_v Coherence per Topic, Multilingual LDA
#
# Per-topic coherence for Multilingual LDA (10 topics). Mean C_v=0.376. Cross-lingual topics across EN/DE/ES/FR/IT show consistent moderate coherence.

# %%
Image('../figures/stage1/lda_coherence_multilingual.png')

# %% [markdown]
# ## 8. Key Findings
#
# **Moderate coherence is expected and acceptable:**
# C_v scores of 0.354-0.392 are typical for short social media texts. Long-form documents score 0.5+. Disinformation claims are brief and noisy.
#
# **High topic distinctiveness:**
# Mean inter-topic distances of 0.921-0.984 confirm topics capture different content domains. English topics cleanly separate political, health, and celebrity content.
#
# **German model strongest on coherence:**
# German LDA achieves C_v=0.392, highest of three models. DeFaktS German tweets show clearer topical separation than English mixed corpus.
#
# **Multilingual model most distinctive:**
# Multilingual LDA achieves mean inter-topic distance of 0.984, cross-lingual topics are maximally distinct.
#
# **Stage 2 GPT-4 verification can proceed:**
# Topic assignments are reliable enough for Stage 2 semantic verification. GPT-4 will validate whether assigned topics correctly categorize disinformation content.
